# %% [markdown]
# # Final Exam
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github//afarbin/DATA1401-Spring-2020/blob/master/Exams/Final/Final.ipynb)

# %% [markdown]
# Recall the drawing system from lecture 18:

# %%
import math
class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def h_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def v_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self,x1,y1,x2,y2,**kargs):
        slope=(y2-y1)/(x2-x1)
        d=1
        if ((x2-x1))<0:
            d=-1
        for x in range(x1,x2,d):
            y=int(slope*(x-x1)+y1)
            # print('{},{}'.format(x,y))
            self.set_pixel(x,y,**kargs)
            
    def arc(self,x,y,a,b,o1,o2,**kargs):
        # o1=int(o1*(math.pi/180))
        # o2=int(o2*(math.pi/180))
        # print('rc {},{}'.format(o1,o2))
        
        for o in range(o1,o2,1):
            # alpha=((a**2)*(math.sin(o*(math.pi/180))**2))+((b**2)*(math.cos(o*(math.pi/180))**2))
            # print(alpha)
            # beta=((a**2)*(math.sin(o*(math.pi/180))*y))+((b**2)*(math.cos(o*(math.pi/180))*x))
            # print(beta)
            # gamma=((a**2)*(y**2))+((b**2)*(x**2))-((a**2)*(b**2))
            # 
            # sqr=(beta**2-alpha*gamma)**0.5
            # print(sqr)
            # r=(beta+(sqr))/(alpha)
            
            axm=(a*b)
            bxm=((b**2)*(math.cos(o*(math.pi/180))**2))+(a**2*(math.sin(o*(math.pi/180))**2))
            r=axm/(bxm**0.5)         
            print(r)
            
            xo=int((abs(r)*math.cos(o*(math.pi/180))))
            yo=int((abs(r)*math.sin(o*(math.pi/180))))
            sx=xo+x
            sy=yo+y
            # print('rc {},{}'.format(xo,yo))
            # print((r.real))
            # if(xo>0 or yo>0):
            self.set_pixel(sx,sy,**kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

# %%
class Shape:
    def __init__(self, name="", **kwargs):
        self.name=name
        self.kwargs=kwargs
        self.print_kwargs = ','.join(["%s=%s"%(key, self.kwargs[key]) for key in self.kwargs])
    
    def paint(self, canvas): pass
    def __str__(self):pass


class Rectangle(Shape):
    def __init__(self,name, x, y, w, h, **kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x = x
        self.y = y
        self.w = w
        self.h = h

    def paint(self, canvas):
        canvas.h_line(self.x, self.y, self.w, **self.kwargs)
        canvas.h_line(self.x, self.y + self.h, self.w, **self.kwargs)
        canvas.v_line(self.x, self.y, self.h, **self.kwargs)
        canvas.v_line(self.x + self.w, self.y, self.h, **self.kwargs)
    def __str__(self):
      if self.print_kwargs:
        output = '%s("%s",%d,%d,%d,%d,%s)' %(self.name,self.x,self.y,self.w,self.h,self.print_kwargs)
      else:
        output = '%s(%d,%d,%d,%d)' %(self.name,self.x,self.y,self.w,self.h)
      return output

class Square(Rectangle):
    def __init__(self,name, x, y, size, **kwargs):
        Rectangle.__init__(self,name, x, y, size, size, **kwargs)

class Line(Shape):
    def __init__(self,name, x1, y1, x2, y2,  **kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x1=x1
        self.y1=y1
        self.x2=x2
        self.y2=y2
        
    def paint(self, canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
        
class CompoundShape(Shape):
    def __init__(self, shapes):
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

# %%
class Shape:
    def __init__(self, name="", **kwargs):
        self.name=name
        self.kwargs=kwargs
        self.print_kwargs = ','.join(['%s="%s"'%(key, self.kwargs[key]) for key in self.kwargs])
    
    def paint(self, canvas): pass
    def __str__(self):pass


class Rectangle(Shape):
    def __init__(self,name, x, y, w, h, **kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x = x
        self.y = y
        self.w = w
        self.h = h

    def paint(self, canvas):
        canvas.h_line(self.x, self.y, self.w, **self.kwargs)
        canvas.h_line(self.x, self.y + self.h, self.w, **self.kwargs)
        canvas.v_line(self.x, self.y, self.h, **self.kwargs)
        canvas.v_line(self.x + self.w, self.y, self.h, **self.kwargs)
    def __str__(self):
      if self.print_kwargs:
        output = '%s("%s",%d,%d,%d,%d,%s)' %(self.name,self.name,self.x,self.y,self.w,self.h,self.print_kwargs)
      else:
        output = '%s("%s",%d,%d,%d,%d)' %(self.name,self.name,self.x,self.y,self.w,self.h)
      return output

class Square(Rectangle):
    def __init__(self,name, x, y, size, **kwargs):
        Rectangle.__init__(self,name, x, y, size, size, **kwargs)
        self.size = size
    
    def __str__(self):
        if self.print_kwargs:
            output = '%s("%s",%d,%d,%d,%s)' %(self.name,self.name,self.x,self.y,self.size,self.print_kwargs)
        else:
            output = '%s("%s",%d,%d,%d)' %(self.name,self.name,self.x,self.y,self.size)
        return output


class Line(Shape):
    def __init__(self,name, x1, y1, x2, y2,  **kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x1=x1
        self.y1=y1
        self.x2=x2
        self.y2=y2

    def __str__(self):
        if self.print_kwargs:
            output = '%s("%s",%d,%d,%d,%d,%s)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2,self.print_kwargs)
        else:
            output = '%s("%s",%d,%d,%d,%d)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2)
        return output
        
    def paint(self, canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
        
class CompoundShape(Shape):
    def __init__(self,name, shapes):
        self.shapes = shapes
        self.name = name

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)
    def __str__(self):
        shapes_string = ','.join([ str(s) for s in self.shapes]) 
        output = "%s(%s,[%s])" % (self.name,self.name,shapes_string)
        return output

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes=dict()
        self.shape_names=list()
        
    def add_shape(self,shape):
        if shape.name == "":
            shape.name = self.assign_name()
        
        self.shapes[shape.name]=shape
        self.shape_names.append(shape.name)
        
    def paint(self,canvas):
        for shape_name in self.shape_names:
            self.shapes[shape_name].paint(canvas)
            
    def assign_name(self):
        name_base="shape"
        name = name_base+"_0"
        
        i=1
        while name in self.shapes:
            name = name_base+"_"+str(i)
            
        return name
    
    def save_file(file_name):
      f = open(file_name,'w')
      for key in self.shapes:
        shape = self.shapes[key]
        f.write(shape)
        f.write('/n')
      f.close()

    def load_file(file_name):
      f = open(file_name,'r')
      for line in f:
        self.add_shape(eval(line))
      f.close()

# %% [markdown]
# 1. Add `Point` and `Triangle` classes and test them.

# %%
class Point(Shape):
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def paint(self,canvas):
        canvas.set_pixel(self.x,self.y)
        
class Triangle(Shape):
    def __init__(self,x1,y1,x2,y2,x3,y3):
        self.x1=x1
        self.y1=y1
        self.x2=x2
        self.y2=y2
        self.x3=x3
        self.y3=y3
    def paint(self,canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
        canvas.line(self.x2,self.y2,self.x3,self.y3)
        canvas.line(self.x3,self.y3,self.x1,self.y1)

# %%
temp=Canvas(10,10)
tri=Triangle(9,1,0,0,5,9)
tri.paint(temp)
temp.display()
print('\n')
temp=Canvas(10,10)
tri=Point(9,1)
tri.paint(temp)
temp.display()
# Out:
# *
# **
# *  *
# *    *
# *      *
# *        *
# *      *
# *    *
# *  *
#  *
#
#
#
#
#
#
#
#
#
#
#
#  *

# %% [markdown]
# 2. Add an `Arc` class that is instantiated with a center location, two axis lengths, and starting and ending angles. If start and end are not specified or are the same angle, the `Arc` instance should draw an oval. If in addition the two axes are the same, the `Arc` instance should draw a circle. Create `Oval` and `Circle` classes that inherit from `Arc`. Test everything.

# %%
class Arc(Shape):
    def __init__(self,x,y,a,b,o1,o2):
        self.x=x
        self.y=y
        self.a=a
        self.b=b
        self.o1=o1
        self.o2=o2
    def paint(self,canvas):
        canvas.arc(self.x,self.y,self.a,self.b,self.o1,self.o2)

class Oval(Arc):
  def __init__(self, x,y, axis1, axis2, angle1, angle2):
    self.__x = x
    self.__y = y
    self.__axis1 = axis1
    self.__axis2 = axis2
    self._angle1 = angle1
    self._angle2 = angle2

class Circle(Arc):
  def __init__(self, x,y, axis1, axis2, angle1, angle2):
    self.__x = x
    self.__y = y
    self.__axis1 = axis1
    self.__axis2 = axis2
    self._angle1 = angle1
    self._angle2 = angle2

# %%
temp=Canvas(100,100)
circle=Arc(50,50,13,13,0,360)  
circle.paint(temp)
temp.display()

#Please scroll below throughly. The drawing is at the bottom.
# Out:
# 13.0
# 12.999999999999998
# 13.0
# 13.000000000000002
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.000000000000002
# 13.0
# 12.999999999999998
# 13.0
# 13.0
# 12.999999999999998
# 12.999999999999998
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 12.999999999999998
# 13.0
# 13.000000000000002
# 13.0
# 12.999999999999998
# 12.999999999999998
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 12.999999999999998
# 13.0
# 13.000000000000002
# 13.0
# 13.0
# 13.0
# 13.0
# 13.000000000000002
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.000000000000002
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 12.999999999999998
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.000000000000002
# 12.999999999999998
# 13.0
# 13.000000000000002
# 13.0
# 13.0
# 13.0
# 13.0
# 13.000000000000002
# 13.0
# 13.0
# 12.999999999999998
# 12.999999999999998
# 13.0
# 13.0
# 13.0
# 12.999999999999998
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.0
# 13.000000000000002
# 13.0
# 12.999999999999998
# 13.0
# 12.999999999999998
# ...

# %%
temp=Canvas(100,100)
oval=Arc(50,50,5,11,0,360)  
oval.paint(temp)
temp.display()
#please scroll below throughly. The drawing is at the bottom.
# Out:
# 5.0
# 5.000604248010509
# 5.002417570188121
# 5.005441701801567
# 5.009679537732107
# 5.015135136618063
# 5.021813726645893
# 5.02972171297596
# 5.038866686786997
# 5.049257435918437
# 5.060903957084231
# 5.073817469625173
# 5.088010430759141
# 5.1034965522794735
# 5.120290818641134
# 5.138409506361662
# 5.157870204649144
# 5.178691837152174
# 5.200894684706448
# 5.2245004089290195
# 5.249532076483675
# 5.276014183808849
# 5.3039726820623025
# 5.333435001993679
# 5.364430078406248
# 5.396988373811499
# 5.431141900813935
# 5.466924242686874
# 5.504370571512164
# 5.543517663155714
# 5.584403908234904
# 5.6270693181012605
# 5.671555524710041
# 5.71790577307512
# 5.766164904809954
# 5.816379331030528
# 5.868596992640733
# 5.92286730573085
# 5.979241089492184
# 6.03777047368115
# 6.098508782249989
# 6.161510389294902
# 6.226830542951087
# 6.2945251522844785
# 6.364650531588348
# 6.437263095787181
# 6.512418999879248
# 6.590173714514507
# 6.670581528909775
# 6.753694971356828
# ...

# %% [markdown]
# 3. Use your classes to create a `RasterDrawing` that draws a happy face.

# %%
temp=Canvas(100,100)
tri=Arc(50,50,10,20,270,450) 
tri.paint(temp)
tri=Arc(50,45,3,3,0,360) 
tri.paint(temp)
tri=Arc(50,55,3,3,0,360) 
tri.paint(temp)
temp.display()
#please scroll below throughly. The drawing is at the bottom.
# Out:
# 20.0
# 19.990868662694595
# 19.96356058370598
# 19.918331400060428
# 19.855600073251328
# 19.77593860019532
# 19.680058301709686
# 19.56879331649237
# 19.443082023356403
# 19.303947159056907
# 19.152475394507928
# 18.989797083907575
# 18.817066817889224
# 18.63544530378107
# 18.44608297437837
# 18.25010560162002
# 18.04860207195928
# 17.842614372686608
# 17.633129747396417
# 17.42107490643166
# 17.207312124880247
# 16.992637025493227
# 16.777777824714747
# 16.56339581425864
# 16.350086855520754
# 16.138383676821043
# 15.928758781509744
# 15.721627796182075
# 15.517353110864699
# 15.316247685699732
# 15.118578920369087
# 14.924572502603617
# 14.734416170207759
# 14.548263336908406
# 14.366236545974038
# 14.188430727023858
# 14.014916240907946
# 13.845741705183723
# 13.680936598754895
# 13.520513648896776
# 13.36447100737585
# 13.21279422487915
# 13.065458034675682
# 12.92242795749494
# 12.783661740160442
# 12.64911064067352
# 12.518720572300847
# 12.392433118856012
# ...

# %% [markdown]
# 4. Add to the `Shape` base class a `__str__()` method. Overwrite the method in each shape to generate a string of the python code necessary to reinstantiate the object. For example, for a rectangle originally instantiated using `Square(5,5,20,char="^")`, `__str__()` should return the string `'Square(5,5,20,char="^")'`.

# %%
class Shape:
    def __init__(self, name="", **kwargs):
        self.name=name
        self.kwargs=kwargs
        self.print_kwargs = ','.join(['%s="%s"'%(key, self.kwargs[key]) for key in self.kwargs])
    
    def paint(self, canvas): pass
    def __str__(self):pass


class Rectangle(Shape):
    def __init__(self,name, x, y, w, h, **kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x = x
        self.y = y
        self.w = w
        self.h = h

    def paint(self, canvas):
        canvas.h_line(self.x, self.y, self.w, **self.kwargs)
        canvas.h_line(self.x, self.y + self.h, self.w, **self.kwargs)
        canvas.v_line(self.x, self.y, self.h, **self.kwargs)
        canvas.v_line(self.x + self.w, self.y, self.h, **self.kwargs)
    def __str__(self):
      if self.print_kwargs:
        output = '%s("%s",%d,%d,%d,%d,%s)' %(self.name,self.name,self.x,self.y,self.w,self.h,self.print_kwargs)
      else:
        output = '%s("%s",%d,%d,%d,%d)' %(self.name,self.name,self.x,self.y,self.w,self.h)
      return output

class Square(Rectangle):
    def __init__(self,name, x, y, size, **kwargs):
        Rectangle.__init__(self,name, x, y, size, size, **kwargs)
        self.size = size
    
    def __str__(self):
        if self.print_kwargs:
            output = '%s("%s",%d,%d,%d,%s)' %(self.name,self.name,self.x,self.y,self.size,self.print_kwargs)
        else:
            output = '%s("%s",%d,%d,%d)' %(self.name,self.name,self.x,self.y,self.size)
        return output


class Line(Shape):
    def __init__(self,name, x1, y1, x2, y2,  **kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x1=x1
        self.y1=y1
        self.x2=x2
        self.y2=y2

    def __str__(self):
        if self.print_kwargs:
            output = '%s("%s",%d,%d,%d,%d,%s)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2,self.print_kwargs)
        else:
            output = '%s("%s",%d,%d,%d,%d)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2)
        return output
        
    def paint(self, canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
        
class CompoundShape(Shape):
    def __init__(self,name, shapes):
        self.shapes = shapes
        self.name = name

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)
    def __str__(self):
        shapes_string = ','.join([ str(s) for s in self.shapes]) 
        output = "%s(%s,[%s])" % (self.name,self.name,shapes_string)
        return output

# %%
class Point(Shape):
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def paint(self,canvas):
        canvas.set_pixel(self.x,self.y)

class Triangle(Shape):
    def __init__(self,name,x1,y1,x2,y2,x3,y3,**kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x1=x1
        self.y1=y1
        self.x2=x2
        self.y2=y2
        self.x3=x3
        self.y3=y3
    def paint(self,canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
        canvas.line(self.x2,self.y2,self.x3,self.y3)
        canvas.line(self.x3,self.y3,self.x1,self.y1)

    def __str__(self):
        if self.print_kwargs:
            output = '%s("%s",%d,%d,%d,%d,%d,%d,%s)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2,self.x3,self.y3,self.print_kwargs)
        else:
            output = '%s("%s",%d,%d,%d,%d,%d,%d)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2,self.x3,self.y3)
        return output
        
    def paint(self, canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
    
class Point(Shape):
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def paint(self,canvas):
        canvas.set_pixel(self.x,self.y)

class Triangle(Shape):
    def __init__(self,name,x1,y1,x2,y2,x3,y3,**kwargs):
        Shape.__init__(self,name, **kwargs)
        self.x1=x1
        self.y1=y1
        self.x2=x2
        self.y2=y2
        self.x3=x3
        self.y3=y3
    def paint(self,canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)
        canvas.line(self.x2,self.y2,self.x3,self.y3)
        canvas.line(self.x3,self.y3,self.x1,self.y1)

    def __str__(self):
        if self.print_kwargs:
            output = '%s("%s",%d,%d,%d,%d,%d,%d,%s)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2,self.x3,self.y3,self.print_kwargs)
        else:
            output = '%s("%s",%d,%d,%d,%d,%d,%d)' %(self.name,self.name,self.x1,self.y1,self.x2,self.y2,self.x3,self.y3)
        return output
        
    def paint(self, canvas):
        canvas.line(self.x1,self.y1,self.x2,self.y2)

# %%
rec = Rectangle("Rectangle",5,7,4,6,char="da",data="hello",text="world")
print(rec)
# Out:
# Rectangle("Rectangle",5,7,4,6,char="da",data="hello",text="world")

# %%
sq = Square("Square",5,7,4)
print(sq)
# Out:
# Square("Square",5,7,4)

# %%
sq = Square("Square",5,7,5,char="da",data="hello",text="world")
print(sq)
# Out:
# Square("Square",5,7,5,char="da",data="hello",text="world")

# %%
l = Line("Line",5,7,5,5)
print(l)
l = Line("Line",5,7,5,5,data="hello",text="world")
print(l)
# Out:
# Line("Line",5,7,5,5)
# Line("Line",5,7,5,5,data="hello",text="world")

# %%
cs = CompoundShape("CompoundShape",[Line("Line",5,7,5,5,data="hello",text="world"),Square("Square",5,7,5,char="da",data="hello",text="world"),Triangle("Triangle",5,7,5,5,6,7,data="hello",text="world")])
print(cs)
# Out:
# CompoundShape(CompoundShape,[Line("Line",5,7,5,5,data="hello",text="world"),Square("Square",5,7,5,char="da",data="hello",text="world"),Triangle("Triangle",5,7,5,5,6,7,data="hello",text="world")])

# %%
tri = Triangle("Triangle",5,7,5,5,6,7)
tri = Triangle("Triangle",5,7,5,5,6,7,data="hello",text="world")
print(tri)
# Out:
# Triangle("Triangle",5,7,5,5,6,7,data="hello",text="world")

# %% [markdown]
# 5. Add to `RasterDrawing` two functions, `save(filename)` and `load(filename)`. The save function writes the `__str__()` of all of the shapes in the drawing to a file (one shape per line). The load function, reads the file, and instantiates each object using the python `eval(expression)` function, and adds each shape to the drawing, thereby recreating a "saved" raster drawing. Use this functionality to save and load your happy face.
#
#    `eval` takes a string that contains a fragment of a python code and executes it. Consider the following examples:

# %%
from google.colab import files
uploaded = files.upload()

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes=dict()
        self.shape_names=list()
        
    def add_shape(self,shape):
        if shape.name == "":
            shape.name = self.assign_name()
        
        self.shapes[shape.name]=shape
        self.shape_names.append(shape.name)
        
    def paint(self,canvas):
        for shape_name in self.shape_names:
            self.shapes[shape_name].paint(canvas)
            
    def assign_name(self):
        name_base="shape"
        name = name_base+"_0"
        
        i=1
        while name in self.shapes:
            name = name_base+"_"+str(i)
            
        return name
    
    def save_file(self, file_name):
      f = open(file_name,'w')
      for key in self.shapes:
        shape = self.shapes[key]
        f.write(shape)
        f.write('/n')
      f.close()

    def load_file(self, file_name):
      f = open(file_name,'r')
      for line in f:
        self.add_shape(eval(line))
      f.close()

# %%
eval("print('Hello')")
# Out:
# Hello

# %%
x = eval('1+2')
print(x)
# Out:
# 3

# %%
RasterDrawing.save_file("smileyFace.txt")

# %%
RasterDrawing.save_file("smileyFace.txt")
